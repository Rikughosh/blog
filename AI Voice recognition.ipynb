# %% [markdown]
# <a href="https://colab.research.google.com/github/Rikughosh/blog/blob/main/AI%20Voice%20recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai-whisper TTS speechbrain librosa torchaudio ffmpeg-python

# %%
import os
import ffmpeg

# Upload the file manually in Colab
from google.colab import files
uploaded = files.upload()

# Convert .m4a to .wav
input_file = next(iter(uploaded))
output_file = input_file.replace('.m4a', '.wav')

ffmpeg.input(input_file).output(output_file).run(overwrite_output=True)
# Out:
#      <input type="file" id="files-dd3cb2d3-d575-4373-b261-38c36be16e1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd3cb2d3-d575-4373-b261-38c36be16e1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install -q SpeechRecognition pydub
# !apt install -y ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %%
from google.colab import files
from pydub import AudioSegment
import os

# Upload audio
uploaded = files.upload()
audio_file = next(iter(uploaded))

# Convert to .wav
if not audio_file.endswith('.wav'):
    sound = AudioSegment.from_file(audio_file)
    wav_file = audio_file.replace('.m4a', '.wav')
    sound.export(wav_file, format="wav")
else:
    wav_file = audio_file
# Out:
#      <input type="file" id="files-ff23589f-bf80-45ba-966e-01e29f85212b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff23589f-bf80-45ba-966e-01e29f85212b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import speech_recognition as sr

recognizer = sr.Recognizer()

with sr.AudioFile(wav_file) as source:
    audio_data = recognizer.record(source)

try:
    text = recognizer.recognize_google(audio_data)
    print("📝 Transcription:\n", text)
except sr.UnknownValueError:
    print("❗Could not understand the audio.")
except sr.RequestError:
    print("❗Could not request results from Google API.")
# Out:
# 📝 Transcription:
#  hi this is your time calling him in private serial am I speaking to Mr ano

# %%
from pathlib import Path

# Create Colab notebook JSON for speech recognition without OpenAI Whisper
notebook_code = """
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🗣️ Speech Recognition in Google Colab (Without Whisper)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# 🔧 Step 1: Install required libraries\\n",
    "!pip install -q SpeechRecognition pydub\\n",
    "!apt install -y ffmpeg"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# 📤 Step 2: Upload and convert your audio file\\n",
    "from google.colab import files\\n",
    "from pydub import AudioSegment\\n",
    "import os\\n",
    "\\n",
    "# Upload audio\\n",
    "uploaded = files.upload()\\n",
    "audio_file = next(iter(uploaded))\\n",
    "\\n",
    "# Convert to .wav if needed\\n",
    "if not audio_file.endswith('.wav'):\\n",
    "    sound = AudioSegment.from_file(audio_file)\\n",
    "    wav_file = audio_file.replace('.m4a', '.wav')\\n",
    "    sound.export(wav_file, format='wav')\\n",
    "else:\\n",
    "    wav_file = audio_file"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# 🧠 Step 3: Run speech recognition using Google's free API\\n",
    "import speech_recognition as sr\\n",
    "\\n",
    "recognizer = sr.Recognizer()\\n",
    "\\n",
    "with sr.AudioFile(wav_file) as source:\\n",
    "    audio_data = recognizer.record(source)\\n",
    "\\n",
    "try:\\n",
    "    text = recognizer.recognize_google(audio_data)\\n",
    "    print('📝 Transcription:\\\\n', text)\\n",
    "except sr.UnknownValueError:\\n",
    "    print('❗Could not understand the audio.')\\n",
    "except sr.RequestError as e:\\n",
    "    print(f'❗API error: {e}')"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": ""
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
"""
